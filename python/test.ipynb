# %%
import os
import json
import requests
import pandas as pd
import numpy as np
import re
import random
import time
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:87: RequestsDependencyWarning: urllib3 (2.2.2) or chardet (4.0.0) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
diff = {
    "youhou": 1,
    "yihi": 8,
}

# %%
for i in diff:
    print(i)
with open("others.json", "w") as outfile:
    json.dump(diff, outfile, indent=4)
# Out:
# youhou
# yihi

# %%
diff2 = {
    "yaha": 42,
    "pope": 0,
}

# %%
for i in diff2:
    print(i)
with open("others.json", "w") as outfile:
    json.dump(diff2, outfile, indent=4)
# Out:
# yaha
# pope
